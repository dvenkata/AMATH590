# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X = np.load('/content/drive/MyDrive/Colab Notebooks/vel3_cutout.npy')
np.swapaxes(X,0,2)
print(X.shape)
# Out:
# (512, 512, 512, 3, 2)

# %%
Y = np.load('/content/drive/MyDrive/Colab Notebooks/vel3_cutout_ld.npy')
np.swapaxes(Y,0,2)
print(Y.shape)
# Out:
# (512, 16, 16, 3, 2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import scipy.ndimage as sp
from skimage.transform import resize

conv = X[:,:,0,2,0]

fig = plt.figure(figsize = (15, 15))
a = fig.add_subplot(131)
a.imshow(conv,
         extent = [0, 3.14, 0, 3.14],
         vmin=-1.5, vmax=1.5)

a = fig.add_subplot(132)
a.imshow(resize(sp.median_filter(conv,size=32),(16,16)),
         extent = [0, 3.14, 0, 3.14],
         vmin=-1.5, vmax=1.5)

a = fig.add_subplot(133)
a.imshow(Y[:,:,0,2,0],
         extent = [0, 3.14, 0, 3.14],
         vmin=-1.5, vmax=1.5)
